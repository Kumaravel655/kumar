# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumaravel655/kumar/blob/main/Detectron2_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5)
# Out:
# 5

# %% [markdown]
# # Install face detection (kumaravel)

# %%
# !python -m pip install cmake
# Detectron2 has not released pre-built binaries for the latest pytorch (https://github.com/facebookresearch/detectron2/issues/4053)
# so we install from source instead. This takes a few minutes.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m pip install face_recognition
# Detectron2 has not released pre-built binaries for the latest pytorch (https://github.com/facebookresearch/detectron2/issues/4053)
# so we install from source instead. This takes a few minutes.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100.1 MB 23 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=5a0c73c238b459296d4ffe0738b76bd7ed902f927e62c703f6c5dd1cf9862243
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
import face_recognition

# %% [markdown]
# # import kumaravel image

# %% [markdown]
# We first download an image from the COCO dataset:

# %%
image = face_recognition.load_image_file("/rdj.jpg")
face_landmarks_list = face_recognition.face_landmarks(image)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
face_landmarks_list
# Out:
# [{'bottom_lip': [(560, 325),
#    (549, 338),
#    (537, 347),
#    (523, 353),
#    (509, 355),
#    (493, 354),
#    (474, 345),
#    (481, 343),
#    (507, 341),
#    (520, 339),
#    (533, 334),
#    (553, 327)],
#   'chin': [(395, 273),
#    (400, 299),
#    (408, 326),
#    (418, 351),
#    (433, 374),
#    (452, 393),
#    (476, 405),
#    (504, 410),
#    (532, 406),
#    (557, 396),
#    (577, 379),
#    (593, 358),
#    (601, 334),
#    (604, 309),
#    (602, 283),
#    (599, 258),
#    (594, 234)],
#   'left_eye': [(433, 251),
#    (442, 238),
#    (456, 235),
#    (472, 244),
#    (459, 249),
#    (444, 253)],
#   'left_eyebrow': [(412, 246), (420, 226), (439, 213), (460, 211), (481, 214)],
#   'nose_bridge': [(500, 231), (504, 249), (508, 267), (512, 285)],
#   'nose_tip': [(490, 304), (502, 305), (514, 305), (524, 300), (533, 295)],
#   'right_eye': [(522, 231),
#    (533, 217),
#    (547, 214),
#    (558, 221),
#    (550, 229),
#    (536, 231)],
# ...
